# %%
import pandas as pd
from scipy.optimize import linprog
import pulp
from pulp import *

# %% [markdown]
# # Import Fantasy Data

# %%
player_info = pd.read_csv("player_historical_info.csv")
df_day1 = pd.read_csv("sixGamePlayoffwindow.csv")

# %%
df_day1.insert(1, 'PLAYER_NAME', value=df_day1['First Name'].str.cat(df_day1['Last Name'], sep=' '))
df_day1.head()
# Out:
#                           ID         PLAYER_NAME First Name    Last Name  \
# 0  nba.p.4387$nba.g.13467906        Derrick Rose    Derrick         Rose
# 1  nba.p.5054$nba.g.13467906       Evan Fournier       Evan     Fournier
# 2  nba.p.5318$nba.g.13467906       Julius Randle     Julius       Randle
# 3  nba.p.5843$nba.g.13467906           Josh Hart       Josh         Hart
# 4  nba.p.5856$nba.g.13467906  Isaiah Hartenstein     Isaiah  Hartenstein
#
#                                         ID + Name Position Team Opponent  \
# 0        nba.p.4387$nba.g.13467906 - Derrick Rose       PG   NY      MIA
# 1       nba.p.5054$nba.g.13467906 - Evan Fournier       SF   NY      MIA
# 2       nba.p.5318$nba.g.13467906 - Julius Randle       PF   NY      MIA
# 3           nba.p.5843$nba.g.13467906 - Josh Hart       SF   NY      MIA
# 4  nba.p.5856$nba.g.13467906 - Isaiah Hartenstein        C   NY      MIA
#
#      Game        Time  Salary  FPPG Injury Status Starting
# 0  NY@MIA  3:30PM EDT      10  10.2
# 1  NY@MIA  3:30PM EDT      10  11.6
# 2  NY@MIA  3:30PM EDT      30  42.2
# 3  NY@MIA  3:30PM EDT      20  27.7
# 4  NY@MIA  3:30PM EDT      10  18.1

# %%
df_day1 = pd.merge(df_day1, player_info, on='PLAYER_NAME')

# %%
df_day1['Ratio'] = df_day1['Y_pred']/df_day1['pred_sigma']

# %%
df_day1.head()
# Out:
#                           ID         PLAYER_NAME First Name    Last Name  \
# 0  nba.p.4387$nba.g.13467906        Derrick Rose    Derrick         Rose
# 1  nba.p.5054$nba.g.13467906       Evan Fournier       Evan     Fournier
# 2  nba.p.5318$nba.g.13467906       Julius Randle     Julius       Randle
# 3  nba.p.5843$nba.g.13467906           Josh Hart       Josh         Hart
# 4  nba.p.5856$nba.g.13467906  Isaiah Hartenstein     Isaiah  Hartenstein
#
#                                         ID + Name Position Team Opponent  \
# 0        nba.p.4387$nba.g.13467906 - Derrick Rose       PG   NY      MIA
# 1       nba.p.5054$nba.g.13467906 - Evan Fournier       SF   NY      MIA
# 2       nba.p.5318$nba.g.13467906 - Julius Randle       PF   NY      MIA
# 3           nba.p.5843$nba.g.13467906 - Josh Hart       SF   NY      MIA
# 4  nba.p.5856$nba.g.13467906 - Isaiah Hartenstein        C   NY      MIA
#
#      Game        Time  Salary  FPPG Injury Status Starting  pred_sigma  \
# 0  NY@MIA  3:30PM EDT      10  10.2                          11.002471
# 1  NY@MIA  3:30PM EDT      10  11.6                           9.550019
# 2  NY@MIA  3:30PM EDT      30  42.2                          10.731120
# 3  NY@MIA  3:30PM EDT      20  27.7                          10.220513
# 4  NY@MIA  3:30PM EDT      10  18.1                          10.099764
#
#       Y_pred     Ratio
# 0  10.467307  0.951360
# 1   0.000000  0.000000
# 2  29.967511  2.792580
# 3  26.263104  2.569646
# 4  20.009524  1.981187

# %% [markdown]
# # Model 1

# %%
# Parameters
S = df_day1["Salary"]
P = df_day1["Position"]
V = df_day1["FPPG"]

#Model
model = LpProblem("FantasyBasketball", LpMaximize)

#Decision Variable
player_vars = LpVariable.dicts("player", df_day1.index, 0, 1, LpBinary)

#Objective
model += lpSum(V[i] * player_vars[i] for i in df_day1.index)

#Constraints
model += sum(S[i] * player_vars[i] for i in df_day1.index) <= 200 # Remain under $200
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Injury Status"] == "INJ") == 0
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Injury Status"] == "O") == 0
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Injury Status"] == "GTD") == 0

##Number of Plyers assigned to position in the line-up
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") <= 4
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") <= 4
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") <=5
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") <=5
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") <= 2

##Number of players in the lineup
model += sum(player_vars[i] for i in df_day1.index) == 8 # Number of pLayers in the line-up

#Solver
status = model.solve()

#Line-up dataframe
if LpStatus[model.status]=="Optimal":
    print("Optimal Line Up:")
    data = []
    for i in df_day1.index:
        if player_vars[i].value()==1:
            data.append([df_day1.loc[i,"ID + Name"], df_day1.loc[i,"Position"], df_day1.loc[i,"Salary"], df_day1.loc[i,"Injury Status"],df_day1.loc[i,"FPPG"]])
            print(df_day1.loc[i,"ID + Name"],"|", df_day1.loc[i,"Position"], "|", df_day1.loc[i,"Salary"], "|", df_day1.loc[i,"Injury Status"], "|",df_day1.loc[i,"FPPG"] )
    
    df_lineup1 = pd.DataFrame(data, columns=["ID + Name", "Position", "Salary", "Injury Status", "FPPG"])
    print(df_lineup1["FPPG"].sum())
else:
    print("No Optimal Line Up Found")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.7/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2f411943077e436e864debfd79298b42-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/2f411943077e436e864debfd79298b42-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 23 COLUMNS
# At line 508 RHS
# At line 527 BOUNDS
# At line 581 ENDATA
# Problem MODEL has 18 rows, 53 columns and 326 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 278.833 - 0.00 seconds
# Cgl0002I 8 variables fixed
# Cgl0004I processed model has 11 rows, 45 columns (45 integer (45 of which binary)) and 225 elements
# Cutoff increment increased from 1e-05 to 0.0999
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.666667
# Cbc0038I Pass   1: suminf.    0.18182 (2) obj. -277.382 iterations 4
# Cbc0038I Solution found of -244.2
# Cbc0038I Before mini branch and bound, 41 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 11 rows 45 columns, reduced to 3 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -244.2 to -275.1 (0.01 seconds)
# Cbc0038I Round again with cutoff of -275.6
# Cbc0038I Reduced cost fixing fixed 27 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.18182 (2) obj. -278.518 iterations 2
# Cbc0038I Pass   3: suminf.    0.42500 (2) obj. -275.6 iterations 3
# Cbc0038I Pass   4: suminf.    0.89839 (3) obj. -275.6 iterations 6
# Cbc0038I Pass   5: suminf.    0.89839 (3) obj. -275.6 iterations 0
# Cbc0038I Pass   6: suminf.    0.48780 (2) obj. -275.6 iterations 2
# Cbc0038I Pass   7: suminf.    0.18182 (2) obj. -278.418 iterations 2
# Cbc0038I Pass   8: suminf.    0.41667 (2) obj. -275.6 iterations 1
# Cbc0038I Pass   9: suminf.    1.07232 (4) obj. -275.6 iterations 5
# Cbc0038I Pass  10: suminf.    0.32975 (3) obj. -275.6 iterations 4
# Cbc0038I Pass  11: suminf.    0.58333 (2) obj. -275.6 iterations 2
# Cbc0038I Pass  12: suminf.    0.48485 (2) obj. -276.782 iterations 1
# Cbc0038I Pass  13: suminf.    0.58333 (2) obj. -275.6 iterations 2
# Cbc0038I Pass  14: suminf.    0.73909 (3) obj. -275.6 iterations 4
# Cbc0038I Pass  15: suminf.    0.40976 (2) obj. -275.6 iterations 1
# Cbc0038I Pass  16: suminf.    1.00000 (3) obj. -275.6 iterations 2
# Cbc0038I Pass  17: suminf.    0.07101 (2) obj. -275.6 iterations 2
# Cbc0038I Pass  18: suminf.    0.07101 (2) obj. -275.6 iterations 0
# Cbc0038I Pass  19: suminf.    0.07101 (2) obj. -275.6 iterations 1
# Cbc0038I Pass  20: suminf.    0.07101 (2) obj. -275.6 iterations 1
# Cbc0038I Pass  21: suminf.    0.88333 (2) obj. -275.6 iterations 6
# Cbc0038I Pass  22: suminf.    0.72727 (2) obj. -277.473 iterations 2
# Cbc0038I Pass  23: suminf.    0.88333 (2) obj. -275.6 iterations 1
# Cbc0038I Pass  24: suminf.    0.79487 (3) obj. -275.6 iterations 8
# Cbc0038I Pass  25: suminf.    0.79487 (3) obj. -275.6 iterations 0
# Cbc0038I Pass  26: suminf.    0.50000 (2) obj. -277.9 iterations 7
# Cbc0038I Solution found of -277
# Cbc0038I Before mini branch and bound, 31 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 11 rows 45 columns, reduced to 9 rows 13 columns
# Cbc0038I Mini branch and bound improved solution from -277 to -277.2 (0.02 seconds)
# Cbc0038I Round again with cutoff of -277.7
# Cbc0038I Reduced cost fixing fixed 34 variables on major pass 3
# Cbc0038I Pass  27: suminf.    0.66667 (2) obj. -278.833 iterations 5
# Cbc0038I Pass  28: suminf.    0.56522 (2) obj. -277.7 iterations 4
# Cbc0038I Pass  29: suminf.    0.80000 (2) obj. -278.78 iterations 2
# Cbc0038I Pass  30: suminf.    0.56522 (2) obj. -277.7 iterations 3
# Cbc0038I Pass  31: suminf.    0.80000 (2) obj. -278.78 iterations 3
# Cbc0038I Pass  32: suminf.    0.94545 (2) obj. -277.7 iterations 3
# Cbc0038I Pass  33: suminf.    0.68571 (4) obj. -277.7 iterations 4
# Cbc0038I Pass  34: suminf.    0.68571 (4) obj. -277.7 iterations 0
# Cbc0038I Pass  35: suminf.    0.68571 (4) obj. -277.7 iterations 0
# Cbc0038I Pass  36: suminf.    0.68571 (4) obj. -277.7 iterations 0
# Cbc0038I Pass  37: suminf.    0.56522 (2) obj. -277.7 iterations 2
# Cbc0038I Pass  38: suminf.    0.68571 (4) obj. -277.7 iterations 3
# Cbc0038I Pass  39: suminf.    0.88889 (2) obj. -278.144 iterations 3
# Cbc0038I Pass  40: suminf.    0.46512 (2) obj. -277.7 iterations 4
# Cbc0038I Pass  41: suminf.    0.80000 (2) obj. -278.78 iterations 3
# Cbc0038I Pass  42: suminf.    0.80000 (2) obj. -278.78 iterations 0
# Cbc0038I Pass  43: suminf.    0.94545 (2) obj. -277.7 iterations 4
# Cbc0038I Pass  44: suminf.    0.88889 (3) obj. -277.7 iterations 5
# Cbc0038I Pass  45: suminf.    0.24419 (4) obj. -277.7 iterations 3
# Cbc0038I Pass  46: suminf.    0.66667 (2) obj. -278.767 iterations 3
# Cbc0038I Pass  47: suminf.    0.66667 (2) obj. -278.767 iterations 0
# Cbc0038I Pass  48: suminf.    0.56522 (2) obj. -277.7 iterations 3
# Cbc0038I Pass  49: suminf.    0.80000 (2) obj. -278.78 iterations 2
# Cbc0038I Pass  50: suminf.    1.43103 (4) obj. -277.7 iterations 3
# Cbc0038I Pass  51: suminf.    1.43103 (4) obj. -277.7 iterations 2
# Cbc0038I Pass  52: suminf.    1.43103 (4) obj. -277.7 iterations 0
# Cbc0038I Pass  53: suminf.    1.43103 (4) obj. -277.7 iterations 0
# Cbc0038I Pass  54: suminf.    1.43103 (4) obj. -277.7 iterations 0
# Cbc0038I Pass  55: suminf.    1.43103 (4) obj. -277.7 iterations 1
# Cbc0038I Pass  56: suminf.    0.68571 (4) obj. -277.7 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 36 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 11 rows 45 columns, reduced to 6 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -277.2 - took 0.01 seconds
# Cbc0012I Integer solution of -277.2 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0038I Full problem 11 rows 45 columns, reduced to 4 rows 5 columns
# Cbc0031I 2 added rows had average density of 5.5
# Cbc0013I At root node, 12 cuts changed objective from -278.83333 to -277.2 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 3 column cuts (3 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 6 row cuts average 4.8 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 18 row cuts average 7.8 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 7 row cuts average 45.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -277.2, took 20 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 37 variables fixed on reduced cost
# Cuts at root node changed objective from -278.833 to -277.2
# Probing was tried 4 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 4 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 4 times and created 18 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 4 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                277.20000000
# Enumerated nodes:               0
# Total iterations:               20
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Optimal Line Up:
# nba.p.5318$nba.g.13467906 - Julius Randle | PF | 30 |   | 42.2
# nba.p.6165$nba.g.13467906 - RJ Barrett | SF | 21 |   | 29.7
# nba.p.6417$nba.g.13467906 - Immanuel Quickley | SG | 13 |   | 26.2
# nba.p.5827$nba.g.13467906 - Bam Adebayo | C | 28 |   | 39.4
# nba.p.4612$nba.g.13468482 - Stephen Curry | PG | 43 |   | 46.7
# nba.p.5292$nba.g.13468482 - Andrew Wiggins | PF | 26 |   | 31.3
# nba.p.6216$nba.g.13468482 - Jordan Poole | PG | 17 |   | 29.8
# nba.p.5433$nba.g.13468482 - D'Angelo Russell | PG | 22 |   | 31.9
# 277.2

# %%
# Parameters
S = df_day1["Salary"]
P = df_day1["Position"]
V = df_day1["Y_pred"]

#Model
model = LpProblem("FantasyBasketball", LpMaximize)

#Decision Variable
player_vars = LpVariable.dicts("player", df_day1.index, 0, 1, LpBinary)

#Objective
model += lpSum(V[i] * player_vars[i] for i in df_day1.index)

#Constraints
model += sum(S[i] * player_vars[i] for i in df_day1.index) <= 200 # Remain under $200
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Injury Status"] == "INJ") == 0
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Injury Status"] == "O") == 0
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Injury Status"] == "GTD") == 0

##Number of Plyers assigned to position in the line-up
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") <= 4
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") <= 4
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") <=5
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") <=5
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") <= 2

##Number of players in the lineup
model += sum(player_vars[i] for i in df_day1.index) == 8 # Number of pLayers in the line-up

#Solver
status = model.solve()

#Line-up dataframe
if LpStatus[model.status]=="Optimal":
    print("Optimal Line Up:")
    data = []
    for i in df_day1.index:
        if player_vars[i].value()==1:
            data.append([df_day1.loc[i,"ID + Name"], df_day1.loc[i,"Position"], df_day1.loc[i,"Salary"], df_day1.loc[i,"Injury Status"],df_day1.loc[i,"FPPG"]])
            print(df_day1.loc[i,"ID + Name"],"|", df_day1.loc[i,"Position"], "|", df_day1.loc[i,"Salary"], "|", df_day1.loc[i,"Injury Status"], "|",df_day1.loc[i,"FPPG"] )
    
    df_lineup1 = pd.DataFrame(data, columns=["ID + Name", "Position", "Salary", "Injury Status", "FPPG"])
    print(df_lineup1["FPPG"].sum())
else:
    print("No Optimal Line Up Found")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.7/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b6b7a22b41c54c708b8c6d58c3f0822c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b6b7a22b41c54c708b8c6d58c3f0822c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 23 COLUMNS
# At line 506 RHS
# At line 525 BOUNDS
# At line 579 ENDATA
# Problem MODEL has 18 rows, 53 columns and 326 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 262.89 - 0.00 seconds
# Cgl0002I 8 variables fixed
# Cgl0004I processed model has 11 rows, 45 columns (45 integer (45 of which binary)) and 225 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.923077
# Cbc0038I Solution found of -260.579
# Cbc0038I Before mini branch and bound, 43 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 11 rows 45 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of -260.81
# Cbc0038I Reduced cost fixing fixed 36 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.07574 (2) obj. -260.81 iterations 3
# Cbc0038I Pass   2: suminf.    0.77778 (2) obj. -261.056 iterations 4
# Cbc0038I Pass   3: suminf.    0.72440 (2) obj. -260.81 iterations 3
# Cbc0038I Pass   4: suminf.    0.72440 (2) obj. -260.81 iterations 1
# Cbc0038I Pass   5: suminf.    0.72440 (2) obj. -260.81 iterations 1
# Cbc0038I Pass   6: suminf.    0.72440 (2) obj. -260.81 iterations 0
# Cbc0038I Pass   7: suminf.    0.72440 (2) obj. -260.81 iterations 1
# Cbc0038I Pass   8: suminf.    0.23529 (2) obj. -261.165 iterations 7
# Cbc0038I Pass   9: suminf.    0.23529 (2) obj. -261.165 iterations 1
# Cbc0038I Pass  10: suminf.    0.35171 (2) obj. -260.81 iterations 2
# Cbc0038I Pass  11: suminf.    0.23529 (2) obj. -261.165 iterations 2
# Cbc0038I Pass  12: suminf.    0.35171 (2) obj. -260.81 iterations 2
# Cbc0038I Pass  13: suminf.    0.59141 (2) obj. -260.81 iterations 5
# Cbc0038I Pass  14: suminf.    0.11111 (2) obj. -262.465 iterations 5
# Cbc0038I Pass  15: suminf.    0.47064 (2) obj. -260.81 iterations 4
# Cbc0038I Pass  16: suminf.    0.83563 (4) obj. -260.81 iterations 4
# Cbc0038I Pass  17: suminf.    0.00933 (2) obj. -260.81 iterations 4
# Cbc0038I Pass  18: suminf.    0.00933 (2) obj. -260.81 iterations 3
# Cbc0038I Pass  19: suminf.    0.77778 (2) obj. -262.006 iterations 5
# Cbc0038I Pass  20: suminf.    0.96241 (2) obj. -260.81 iterations 3
# Cbc0038I Pass  21: suminf.    0.68530 (3) obj. -260.81 iterations 5
# Cbc0038I Pass  22: suminf.    0.56350 (3) obj. -260.81 iterations 3
# Cbc0038I Pass  23: suminf.    0.96776 (2) obj. -260.81 iterations 2
# Cbc0038I Pass  24: suminf.    0.33333 (2) obj. -262.49 iterations 3
# Cbc0038I Pass  25: suminf.    0.11111 (2) obj. -262.465 iterations 4
# Cbc0038I Pass  26: suminf.    0.47064 (2) obj. -260.81 iterations 4
# Cbc0038I Pass  27: suminf.    0.35171 (2) obj. -260.81 iterations 3
# Cbc0038I Pass  28: suminf.    0.23529 (2) obj. -261.165 iterations 2
# Cbc0038I Pass  29: suminf.    0.35171 (2) obj. -260.81 iterations 3
# Cbc0038I Pass  30: suminf.    0.23529 (2) obj. -261.165 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 37 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 11 rows 45 columns, reduced to 7 rows 8 columns
# Cbc0038I Mini branch and bound improved solution from -260.579 to -260.788 (0.01 seconds)
# Cbc0038I Round again with cutoff of -261.226
# Cbc0038I Reduced cost fixing fixed 36 variables on major pass 3
# Cbc0038I Pass  30: suminf.    0.21206 (2) obj. -261.226 iterations 0
# Cbc0038I Pass  31: suminf.    1.03325 (4) obj. -261.226 iterations 4
# Cbc0038I Pass  32: suminf.    1.03325 (4) obj. -261.226 iterations 2
# Cbc0038I Pass  33: suminf.    1.15367 (4) obj. -261.226 iterations 2
# Cbc0038I Pass  34: suminf.    1.03325 (4) obj. -261.226 iterations 2
# Cbc0038I Pass  35: suminf.    1.03325 (4) obj. -261.226 iterations 0
# Cbc0038I Pass  36: suminf.    1.03325 (4) obj. -261.226 iterations 0
# Cbc0038I Pass  37: suminf.    1.21579 (4) obj. -261.226 iterations 1
# Cbc0038I Pass  38: suminf.    1.03325 (4) obj. -261.226 iterations 3
# Cbc0038I Pass  39: suminf.    1.21579 (4) obj. -261.226 iterations 2
# Cbc0038I Pass  40: suminf.    1.21579 (4) obj. -261.226 iterations 0
# Cbc0038I Pass  41: suminf.    0.28571 (2) obj. -262.634 iterations 6
# Cbc0038I Pass  42: suminf.    0.11111 (2) obj. -262.465 iterations 4
# Cbc0038I Pass  43: suminf.    0.38027 (2) obj. -261.226 iterations 3
# Cbc0038I Pass  44: suminf.    0.11111 (2) obj. -262.465 iterations 3
# Cbc0038I Pass  45: suminf.    0.38027 (2) obj. -261.226 iterations 3
# Cbc0038I Pass  46: suminf.    0.72958 (2) obj. -261.226 iterations 2
# Cbc0038I Pass  47: suminf.    0.33333 (2) obj. -262.49 iterations 4
# Cbc0038I Pass  48: suminf.    0.95823 (3) obj. -261.226 iterations 4
# Cbc0038I Pass  49: suminf.    0.77778 (2) obj. -262.006 iterations 4
# Cbc0038I Pass  50: suminf.    0.94722 (2) obj. -261.226 iterations 3
# Cbc0038I Pass  51: suminf.    0.94722 (2) obj. -261.226 iterations 0
# Cbc0038I Pass  52: suminf.    0.55642 (4) obj. -261.226 iterations 9
# Cbc0038I Pass  53: suminf.    0.57239 (3) obj. -261.226 iterations 1
# Cbc0038I Pass  54: suminf.    0.83144 (2) obj. -261.226 iterations 2
# Cbc0038I Pass  55: suminf.    0.83144 (2) obj. -261.226 iterations 1
# Cbc0038I Pass  56: suminf.    0.95823 (3) obj. -261.226 iterations 5
# Cbc0038I Pass  57: suminf.    0.77778 (2) obj. -262.006 iterations 4
# Cbc0038I Pass  58: suminf.    0.18271 (2) obj. -261.226 iterations 2
# Cbc0038I Pass  59: suminf.    0.18271 (2) obj. -261.226 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 37 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 11 rows 45 columns, reduced to 7 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -260.788 - took 0.01 seconds
# Cbc0012I Integer solution of -260.78781 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 11 rows 45 columns, reduced to 4 rows 4 columns
# Cbc0031I 5 added rows had average density of 4
# Cbc0013I At root node, 13 cuts changed objective from -262.88961 to -260.78781 in 7 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 11 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 8.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 39 row cuts average 7.6 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 3 row cuts average 45.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -260.78781194, took 36 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 36 variables fixed on reduced cost
# Cuts at root node changed objective from -262.89 to -260.788
# Probing was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 7 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 7 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 7 times and created 39 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 7 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                260.78781194
# Enumerated nodes:               0
# Total iterations:               36
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Optimal Line Up:
# nba.p.6165$nba.g.13467906 - RJ Barrett | SF | 21 |   | 29.7
# nba.p.4391$nba.g.13467906 - Kevin Love | PF | 11 |   | 19.1
# nba.p.5827$nba.g.13467906 - Bam Adebayo | C | 28 |   | 39.4
# nba.p.4612$nba.g.13468482 - Stephen Curry | PG | 43 |   | 46.7
# nba.p.4892$nba.g.13468482 - Klay Thompson | SG | 22 |   | 31.7
# nba.p.5069$nba.g.13468482 - Draymond Green | C | 25 |   | 30.6
# nba.p.5292$nba.g.13468482 - Andrew Wiggins | PF | 26 |   | 31.3
# nba.p.5433$nba.g.13468482 - D'Angelo Russell | PG | 22 |   | 31.9
# 260.4
