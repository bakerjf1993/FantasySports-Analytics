# %%
import pandas as pd
from scipy.optimize import linprog
import pulp
from pulp import *

# %% [markdown]
# # Import Fantasy Data

# %%
player_info = pd.read_csv("player_historical_info.csv")
df_day1 = pd.read_csv("sixGamePlayoffwindow.csv")

# %%
df_day1.insert(1, 'PLAYER_NAME', value=df_day1['First Name'].str.cat(df_day1['Last Name'], sep=' '))
df_day1.head()
# Out:
#                           ID         PLAYER_NAME First Name    Last Name  \
# 0  nba.p.4387$nba.g.13467906        Derrick Rose    Derrick         Rose
# 1  nba.p.5054$nba.g.13467906       Evan Fournier       Evan     Fournier
# 2  nba.p.5318$nba.g.13467906       Julius Randle     Julius       Randle
# 3  nba.p.5843$nba.g.13467906           Josh Hart       Josh         Hart
# 4  nba.p.5856$nba.g.13467906  Isaiah Hartenstein     Isaiah  Hartenstein
#
#                                         ID + Name Position Team Opponent  \
# 0        nba.p.4387$nba.g.13467906 - Derrick Rose       PG   NY      MIA
# 1       nba.p.5054$nba.g.13467906 - Evan Fournier       SF   NY      MIA
# 2       nba.p.5318$nba.g.13467906 - Julius Randle       PF   NY      MIA
# 3           nba.p.5843$nba.g.13467906 - Josh Hart       SF   NY      MIA
# 4  nba.p.5856$nba.g.13467906 - Isaiah Hartenstein        C   NY      MIA
#
#      Game        Time  Salary  FPPG Injury Status Starting
# 0  NY@MIA  3:30PM EDT      10  10.2
# 1  NY@MIA  3:30PM EDT      10  11.6
# 2  NY@MIA  3:30PM EDT      30  42.2
# 3  NY@MIA  3:30PM EDT      20  27.7
# 4  NY@MIA  3:30PM EDT      10  18.1

# %%
df_day1 = pd.merge(df_day1, player_info, on='PLAYER_NAME')

# %%
df_day1['Ratio'] = df_day1['Y_pred']/df_day1['pred_sigma']

# %%
df_day1.head()
# Out:
#                           ID         PLAYER_NAME First Name    Last Name  \
# 0  nba.p.4387$nba.g.13467906        Derrick Rose    Derrick         Rose
# 1  nba.p.5054$nba.g.13467906       Evan Fournier       Evan     Fournier
# 2  nba.p.5318$nba.g.13467906       Julius Randle     Julius       Randle
# 3  nba.p.5843$nba.g.13467906           Josh Hart       Josh         Hart
# 4  nba.p.5856$nba.g.13467906  Isaiah Hartenstein     Isaiah  Hartenstein
#
#                                         ID + Name Position Team Opponent  \
# 0        nba.p.4387$nba.g.13467906 - Derrick Rose       PG   NY      MIA
# 1       nba.p.5054$nba.g.13467906 - Evan Fournier       SF   NY      MIA
# 2       nba.p.5318$nba.g.13467906 - Julius Randle       PF   NY      MIA
# 3           nba.p.5843$nba.g.13467906 - Josh Hart       SF   NY      MIA
# 4  nba.p.5856$nba.g.13467906 - Isaiah Hartenstein        C   NY      MIA
#
#      Game        Time  Salary  FPPG Injury Status Starting  pred_sigma  \
# 0  NY@MIA  3:30PM EDT      10  10.2                          11.002471
# 1  NY@MIA  3:30PM EDT      10  11.6                           9.550019
# 2  NY@MIA  3:30PM EDT      30  42.2                          10.731120
# 3  NY@MIA  3:30PM EDT      20  27.7                          10.220513
# 4  NY@MIA  3:30PM EDT      10  18.1                          10.099764
#
#       Y_pred     Ratio
# 0  10.467307  0.951360
# 1   0.000000  0.000000
# 2  29.967511  2.792580
# 3  26.263104  2.569646
# 4  20.009524  1.981187

# %% [markdown]
# # Model 1

# %%
# Parameters
S = df_day1["Salary"]
P = df_day1["Position"]
V = df_day1["FPPG"]

#Model
model = LpProblem("FantasyBasketball", LpMaximize)

#Decision Variable
player_vars = LpVariable.dicts("player", df_day1.index, 0, 1, LpBinary)

#Objective
model += lpSum(V[i] * player_vars[i] for i in df_day1.index)

#Constraints
model += sum(S[i] * player_vars[i] for i in df_day1.index) <= 200 # Remain under $200
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Injury Status"] == "INJ") == 0
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Injury Status"] == "O") == 0
#model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Injury Status"] == "GTD") == 0

##Number of Plyers assigned to position in the line-up
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") <= 4
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") <= 4
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") <=5
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") <=5
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") <= 2

##Number of players in the lineup
model += sum(player_vars[i] for i in df_day1.index) == 8 # Number of pLayers in the line-up

#Solver
status = model.solve()

#Line-up dataframe
if LpStatus[model.status]=="Optimal":
    print("Optimal Line Up:")
    data = []
    for i in df_day1.index:
        if player_vars[i].value()==1:
            data.append([df_day1.loc[i,"ID + Name"], df_day1.loc[i,"Position"], df_day1.loc[i,"Salary"], df_day1.loc[i,"Injury Status"],df_day1.loc[i,"FPPG"], df_day1.loc[i,"Y_pred"]])
            print(df_day1.loc[i,"ID + Name"],"|", df_day1.loc[i,"Position"], "|", df_day1.loc[i,"Salary"], "|", df_day1.loc[i,"Injury Status"], "|",df_day1.loc[i,"FPPG"], "|", df_day1.loc[i,"Y_pred"] )
    
    df_lineup1 = pd.DataFrame(data, columns=["ID + Name", "Position", "Salary", "Injury Status", "FPPG","Y_pred"])
    print(df_lineup1["FPPG"].sum())
else:
    print("No Optimal Line Up Found")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.7/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9d8019fc6a1948aa8db59bb3140f554f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/9d8019fc6a1948aa8db59bb3140f554f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 22 COLUMNS
# At line 501 RHS
# At line 519 BOUNDS
# At line 573 ENDATA
# Problem MODEL has 17 rows, 53 columns and 320 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 283.438 - 0.00 seconds
# Cgl0002I 2 variables fixed
# Cgl0004I processed model has 11 rows, 51 columns (51 integer (51 of which binary)) and 255 elements
# Cutoff increment increased from 1e-05 to 0.0999
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.108108
# Cbc0038I Solution found of -282
# Cbc0038I Before mini branch and bound, 49 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 11 rows 51 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of -282.3
# Cbc0038I Reduced cost fixing fixed 40 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.02256 (2) obj. -282.3 iterations 3
# Cbc0038I Pass   2: suminf.    0.25000 (2) obj. -282.613 iterations 3
# Cbc0038I Pass   3: suminf.    0.22896 (2) obj. -282.3 iterations 1
# Cbc0038I Pass   4: suminf.    0.64840 (3) obj. -282.3 iterations 2
# Cbc0038I Pass   5: suminf.    0.22896 (2) obj. -282.3 iterations 2
# Cbc0038I Pass   6: suminf.    0.65962 (4) obj. -282.3 iterations 3
# Cbc0038I Pass   7: suminf.    0.31438 (3) obj. -282.3 iterations 4
# Cbc0038I Pass   8: suminf.    0.64828 (3) obj. -282.3 iterations 1
# Cbc0038I Pass   9: suminf.    1.00000 (3) obj. -282.3 iterations 6
# Cbc0038I Pass  10: suminf.    1.00000 (3) obj. -282.3 iterations 2
# Cbc0038I Pass  11: suminf.    0.21429 (2) obj. -282.696 iterations 3
# Cbc0038I Pass  12: suminf.    0.15929 (2) obj. -282.3 iterations 2
# Cbc0038I Pass  13: suminf.    0.44941 (3) obj. -282.3 iterations 3
# Cbc0038I Pass  14: suminf.    0.97333 (3) obj. -282.3 iterations 7
# Cbc0038I Pass  15: suminf.    0.22896 (2) obj. -282.3 iterations 4
# Cbc0038I Pass  16: suminf.    0.25000 (2) obj. -282.613 iterations 1
# Cbc0038I Pass  17: suminf.    0.22896 (2) obj. -282.3 iterations 1
# Cbc0038I Pass  18: suminf.    0.25000 (2) obj. -282.613 iterations 1
# Cbc0038I Pass  19: suminf.    0.90544 (3) obj. -282.3 iterations 5
# Cbc0038I Pass  20: suminf.    0.90544 (3) obj. -282.3 iterations 0
# Cbc0038I Pass  21: suminf.    0.61667 (2) obj. -282.3 iterations 3
# Cbc0038I Pass  22: suminf.    0.60606 (2) obj. -282.427 iterations 1
# Cbc0038I Pass  23: suminf.    0.88215 (2) obj. -282.3 iterations 2
# Cbc0038I Pass  24: suminf.    0.85000 (2) obj. -282.778 iterations 1
# Cbc0038I Pass  25: suminf.    0.02256 (2) obj. -282.3 iterations 4
# Cbc0038I Pass  26: suminf.    0.02256 (2) obj. -282.3 iterations 0
# Cbc0038I Pass  27: suminf.    0.25000 (2) obj. -282.613 iterations 3
# Cbc0038I Pass  28: suminf.    0.22896 (2) obj. -282.3 iterations 1
# Cbc0038I Pass  29: suminf.    0.70391 (3) obj. -282.3 iterations 1
# Cbc0038I Pass  30: suminf.    0.22896 (2) obj. -282.3 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 40 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 11 rows 51 columns, reduced to 7 rows 11 columns
# Cbc0038I Mini branch and bound improved solution from -282 to -282.1 (0.01 seconds)
# Cbc0038I Round again with cutoff of -282.6
# Cbc0038I Reduced cost fixing fixed 42 variables on major pass 3
# Cbc0038I Pass  30: suminf.    0.04511 (2) obj. -282.6 iterations 0
# Cbc0038I Pass  31: suminf.    0.88889 (3) obj. -282.6 iterations 3
# Cbc0038I Pass  32: suminf.    1.00000 (3) obj. -282.6 iterations 2
# Cbc0038I Pass  33: suminf.    0.99454 (3) obj. -282.6 iterations 2
# Cbc0038I Pass  34: suminf.    0.92558 (3) obj. -282.6 iterations 2
# Cbc0038I Pass  35: suminf.    0.57895 (2) obj. -282.6 iterations 5
# Cbc0038I Pass  36: suminf.    0.57895 (2) obj. -282.6 iterations 0
# Cbc0038I Pass  37: suminf.    0.78853 (3) obj. -282.6 iterations 3
# Cbc0038I Pass  38: suminf.    1.00000 (3) obj. -282.6 iterations 1
# Cbc0038I Pass  39: suminf.    0.99454 (3) obj. -282.6 iterations 3
# Cbc0038I Pass  40: suminf.    0.92558 (3) obj. -282.6 iterations 2
# Cbc0038I Pass  41: suminf.    0.57895 (2) obj. -282.6 iterations 5
# Cbc0038I Pass  42: suminf.    0.57895 (2) obj. -282.6 iterations 0
# Cbc0038I Pass  43: suminf.    0.78853 (3) obj. -282.6 iterations 3
# Cbc0038I Pass  44: suminf.    0.44444 (2) obj. -283.222 iterations 7
# Cbc0038I Pass  45: suminf.    0.04511 (2) obj. -282.6 iterations 3
# Cbc0038I Pass  46: suminf.    0.88889 (3) obj. -282.6 iterations 3
# Cbc0038I Pass  47: suminf.    0.62687 (4) obj. -282.6 iterations 5
# Cbc0038I Pass  48: suminf.    0.20488 (2) obj. -282.6 iterations 3
# Cbc0038I Pass  49: suminf.    0.64865 (2) obj. -283.027 iterations 2
# Cbc0038I Pass  50: suminf.    0.61654 (2) obj. -282.6 iterations 1
# Cbc0038I Pass  51: suminf.    1.31476 (4) obj. -282.6 iterations 1
# Cbc0038I Pass  52: suminf.    0.61654 (2) obj. -282.6 iterations 1
# Cbc0038I Pass  53: suminf.    1.00000 (3) obj. -282.6 iterations 4
# Cbc0038I Pass  54: suminf.    1.00000 (3) obj. -282.6 iterations 0
# Cbc0038I Pass  55: suminf.    0.61654 (2) obj. -282.6 iterations 4
# Cbc0038I Pass  56: suminf.    0.20488 (2) obj. -282.6 iterations 1
# Cbc0038I Pass  57: suminf.    0.20488 (2) obj. -282.6 iterations 0
# Cbc0038I Pass  58: suminf.    0.64865 (2) obj. -283.027 iterations 3
# Cbc0038I Pass  59: suminf.    0.61654 (2) obj. -282.6 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 42 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 11 rows 51 columns, reduced to 7 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -282.1 - took 0.01 seconds
# Cbc0012I Integer solution of -282.1 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 11 rows 51 columns, reduced to 5 rows 6 columns
# Cbc0031I 4 added rows had average density of 6
# Cbc0013I At root node, 17 cuts changed objective from -283.43784 to -282 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 6 row cuts average 3.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 3 row cuts average 8.3 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 14 row cuts average 7.4 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 5 row cuts average 51.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -282.1, took 14 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 42 variables fixed on reduced cost
# Cuts at root node changed objective from -283.438 to -282
# Probing was tried 3 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 3 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 3 times and created 14 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 3 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                282.10000000
# Enumerated nodes:               0
# Total iterations:               14
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Optimal Line Up:
# nba.p.5318$nba.g.13467906 - Julius Randle | PF | 30 |   | 42.2 | 29.96751096
# nba.p.6417$nba.g.13467906 - Immanuel Quickley | SG | 13 |   | 26.2 | 15.81539634
# nba.p.4152$nba.g.13467906 - Kyle Lowry | PG | 13 |   | 25.8 | 26.63011907
# nba.p.5827$nba.g.13467906 - Bam Adebayo | C | 28 |   | 39.4 | 33.95470936
# nba.p.4612$nba.g.13468482 - Stephen Curry | PG | 43 |   | 46.7 | 45.50355517
# nba.p.6028$nba.g.13468482 - Donte DiVincenzo | SF | 11 |   | 22.1 | 18.36498044
# nba.p.6216$nba.g.13468482 - Jordan Poole | PG | 17 |   | 29.8 | 21.56493944
# nba.p.3704$nba.g.13468482 - LeBron James | SF | 45 | GTD | 49.9 | 44.91968813
# 282.1

# %% [markdown]
# # Model 2

# %%
# Parameters
S = df_day1["Salary"]
P = df_day1["Position"]
V = df_day1["Y_pred"]

#Model
model = LpProblem("FantasyBasketball", LpMaximize)

#Decision Variable
player_vars = LpVariable.dicts("player", df_day1.index, 0, 1, LpBinary)

#Objective
model += lpSum(V[i] * player_vars[i] for i in df_day1.index)

#Constraints
model += sum(S[i] * player_vars[i] for i in df_day1.index) <= 200 # Remain under $200
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Injury Status"] == "INJ") == 0
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Injury Status"] == "O") == 0
#model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Injury Status"] == "GTD") == 0

##Number of Plyers assigned to position in the line-up
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") <= 4
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") <= 4
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") <= 3
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PG") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SG") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") <=5
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "SF") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "PF") + sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") <=5
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") >= 1
model += sum(player_vars[i] for i in df_day1.index if df_day1.loc[i, "Position"] == "C") <= 2

##Number of players in the lineup
model += sum(player_vars[i] for i in df_day1.index) == 8 # Number of pLayers in the line-up

#Solver
status = model.solve()

#Line-up dataframe
if LpStatus[model.status]=="Optimal":
    print("Optimal Line Up:")
    data = []
    for i in df_day1.index:
        if player_vars[i].value()==1:
            data.append([df_day1.loc[i,"ID + Name"], df_day1.loc[i,"Position"], df_day1.loc[i,"Salary"], df_day1.loc[i,"Injury Status"],df_day1.loc[i,"FPPG"], df_day1.loc[i,"Y_pred"]])
            print(df_day1.loc[i,"ID + Name"],"|", df_day1.loc[i,"Position"], "|", df_day1.loc[i,"Salary"], "|", df_day1.loc[i,"Injury Status"], "|",df_day1.loc[i,"FPPG"], "|", df_day1.loc[i,"Y_pred"] )
    
    df_lineup1 = pd.DataFrame(data, columns=["ID + Name", "Position", "Salary", "Injury Status", "FPPG","Y_pred"])
    print(df_lineup1["FPPG"].sum())
else:
    print("No Optimal Line Up Found")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.7/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/bd08e206774e467bb970f0bef0ff51d6-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/bd08e206774e467bb970f0bef0ff51d6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 22 COLUMNS
# At line 499 RHS
# At line 517 BOUNDS
# At line 571 ENDATA
# Problem MODEL has 17 rows, 53 columns and 320 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 275.936 - 0.00 seconds
# Cgl0002I 2 variables fixed
# Cgl0004I processed model has 11 rows, 51 columns (51 integer (51 of which binary)) and 255 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.473684
# Cbc0038I Solution found of -270.018
# Cbc0038I Before mini branch and bound, 49 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 11 rows 51 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of -270.61
# Cbc0038I Reduced cost fixing fixed 29 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.04737 (2) obj. -270.61 iterations 3
# Cbc0038I Pass   2: suminf.    0.55000 (2) obj. -272.67 iterations 4
# Cbc0038I Pass   3: suminf.    0.41623 (2) obj. -270.61 iterations 2
# Cbc0038I Pass   4: suminf.    0.55682 (3) obj. -270.61 iterations 7
# Cbc0038I Pass   5: suminf.    0.55682 (3) obj. -270.61 iterations 2
# Cbc0038I Pass   6: suminf.    0.69595 (2) obj. -270.61 iterations 5
# Cbc0038I Pass   7: suminf.    0.57430 (3) obj. -270.61 iterations 5
# Cbc0038I Pass   8: suminf.    0.81629 (2) obj. -270.61 iterations 5
# Cbc0038I Pass   9: suminf.    0.42424 (2) obj. -273.396 iterations 4
# Cbc0038I Pass  10: suminf.    0.63589 (2) obj. -270.61 iterations 2
# Cbc0038I Pass  11: suminf.    1.22530 (4) obj. -270.61 iterations 10
# Cbc0038I Pass  12: suminf.    0.86383 (3) obj. -270.61 iterations 4
# Cbc0038I Pass  13: suminf.    0.93611 (2) obj. -270.61 iterations 2
# Cbc0038I Pass  14: suminf.    0.93611 (2) obj. -270.61 iterations 1
# Cbc0038I Pass  15: suminf.    0.85000 (2) obj. -272.242 iterations 3
# Cbc0038I Pass  16: suminf.    0.95600 (2) obj. -270.61 iterations 1
# Cbc0038I Pass  17: suminf.    0.40377 (2) obj. -270.61 iterations 6
# Cbc0038I Pass  18: suminf.    0.13147 (2) obj. -270.61 iterations 2
# Cbc0038I Pass  19: suminf.    0.55000 (2) obj. -272.67 iterations 3
# Cbc0038I Pass  20: suminf.    0.41623 (2) obj. -270.61 iterations 2
# Cbc0038I Pass  21: suminf.    0.06061 (2) obj. -275.266 iterations 5
# Cbc0038I Pass  22: suminf.    0.06061 (2) obj. -275.266 iterations 2
# Cbc0038I Pass  23: suminf.    0.64454 (2) obj. -270.61 iterations 3
# Cbc0038I Pass  24: suminf.    0.40000 (2) obj. -274.376 iterations 2
# Cbc0038I Pass  25: suminf.    0.90579 (3) obj. -270.61 iterations 8
# Cbc0038I Solution found of -272.727
# Cbc0038I Before mini branch and bound, 34 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 11 rows 51 columns, reduced to 8 rows 13 columns
# Cbc0038I Mini branch and bound improved solution from -272.727 to -274.491 (0.01 seconds)
# Cbc0038I Round again with cutoff of -274.78
# Cbc0038I Reduced cost fixing fixed 41 variables on major pass 3
# Cbc0038I Pass  26: suminf.    0.38119 (2) obj. -274.78 iterations 0
# Cbc0038I Pass  27: suminf.    0.86589 (3) obj. -274.78 iterations 4
# Cbc0038I Pass  28: suminf.    0.86589 (3) obj. -274.78 iterations 0
# Cbc0038I Pass  29: suminf.    0.03061 (2) obj. -274.78 iterations 5
# Cbc0038I Pass  30: suminf.    0.02817 (2) obj. -274.78 iterations 2
# Cbc0038I Pass  31: suminf.    0.02817 (2) obj. -274.78 iterations 0
# Cbc0038I Pass  32: suminf.    0.73433 (3) obj. -274.78 iterations 6
# Cbc0038I Pass  33: suminf.    0.02817 (2) obj. -274.78 iterations 7
# Cbc0038I Pass  34: suminf.    0.03061 (2) obj. -274.78 iterations 3
# Cbc0038I Pass  35: suminf.    0.02817 (2) obj. -274.78 iterations 2
# Cbc0038I Pass  36: suminf.    1.00000 (3) obj. -274.78 iterations 6
# Cbc0038I Pass  37: suminf.    0.55912 (3) obj. -274.78 iterations 1
# Cbc0038I Pass  38: suminf.    0.55912 (3) obj. -274.78 iterations 2
# Cbc0038I Pass  39: suminf.    0.03061 (2) obj. -274.78 iterations 5
# Cbc0038I Pass  40: suminf.    0.02817 (2) obj. -274.78 iterations 2
# Cbc0038I Pass  41: suminf.    0.86589 (3) obj. -274.78 iterations 4
# Cbc0038I Pass  42: suminf.    0.86589 (3) obj. -274.78 iterations 0
# Cbc0038I Pass  43: suminf.    0.86589 (3) obj. -274.78 iterations 1
# Cbc0038I Pass  44: suminf.    0.86589 (3) obj. -274.78 iterations 1
# Cbc0038I Pass  45: suminf.    0.03061 (2) obj. -274.78 iterations 5
# Cbc0038I Pass  46: suminf.    0.02817 (2) obj. -274.78 iterations 2
# Cbc0038I Pass  47: suminf.    0.86589 (3) obj. -274.78 iterations 4
# Cbc0038I Pass  48: suminf.    0.86589 (3) obj. -274.78 iterations 0
# Cbc0038I Pass  49: suminf.    1.00000 (3) obj. -274.78 iterations 1
# Cbc0038I Pass  50: suminf.    1.00000 (3) obj. -274.78 iterations 2
# Cbc0038I Pass  51: suminf.    0.41026 (2) obj. -274.859 iterations 4
# Cbc0038I Pass  52: suminf.    0.41026 (2) obj. -274.859 iterations 0
# Cbc0038I Pass  53: suminf.    0.41596 (2) obj. -274.78 iterations 1
# Cbc0038I Pass  54: suminf.    0.57564 (4) obj. -274.78 iterations 3
# Cbc0038I Pass  55: suminf.    0.06250 (2) obj. -275.339 iterations 8
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 44 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 11 rows 51 columns, reduced to 3 rows 5 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -274.491 - took 0.01 seconds
# Cbc0012I Integer solution of -274.49129 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 11 rows 51 columns, reduced to 2 rows 3 columns
# Cbc0031I 3 added rows had average density of 6
# Cbc0013I At root node, 16 cuts changed objective from -275.93566 to -274.49129 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 8 row cuts average 4.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 5 row cuts average 7.8 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 24 row cuts average 7.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -274.49129036, took 17 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 43 variables fixed on reduced cost
# Cuts at root node changed objective from -275.936 to -274.491
# Probing was tried 4 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 4 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 4 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 4 times and created 24 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                274.49129036
# Enumerated nodes:               0
# Total iterations:               17
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Optimal Line Up:
# nba.p.6165$nba.g.13467906 - RJ Barrett | SF | 21 |   | 29.7 | 29.60045631
# nba.p.4152$nba.g.13467906 - Kyle Lowry | PG | 13 |   | 25.8 | 26.63011907
# nba.p.4391$nba.g.13467906 - Kevin Love | PF | 11 |   | 19.1 | 25.45299408
# nba.p.4912$nba.g.13467906 - Jimmy Butler | PF | 44 | GTD | 43.9 | 51.4728525
# nba.p.6353$nba.g.13467906 - Gabe Vincent | PG | 12 |   | 17.6 | 24.99070399
# nba.p.4892$nba.g.13468482 - Klay Thompson | SG | 22 |   | 31.7 | 30.44568437
# nba.p.5069$nba.g.13468482 - Draymond Green | C | 25 |   | 30.6 | 35.92148729
# nba.p.5007$nba.g.13468482 - Anthony Davis | C | 50 | GTD | 52.4 | 49.97699275
# 250.8
